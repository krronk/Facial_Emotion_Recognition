# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Fri Jun 11 09:50:49 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
root_dir = '/content/drive/MyDrive/Single Emotions (1)/Train_set'
import os
os.listdir(root_dir)
# Out:
# ['Train', 'train_labels.csv']

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
pip install https://github.com/ufoym/imbalanced-dataset-sampler/archive/master.zip
# Out:
# Collecting https://github.com/ufoym/imbalanced-dataset-sampler/archive/master.zip
#   Downloading https://github.com/ufoym/imbalanced-dataset-sampler/archive/master.zip
#      \ 348kB 5.1MB/s
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.7/dist-packages (from torchsampler==0.1.1) (1.8.1+cu101)
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.7/dist-packages (from torchsampler==0.1.1) (0.9.1+cu101)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torchsampler==0.1.1) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch>=1.3->torchsampler==0.1.1) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3->torchsampler==0.1.1) (3.7.4.3)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5->torchsampler==0.1.1) (7.1.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->torchsampler==0.1.1) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torchsampler==0.1.1) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torchsampler==0.1.1) (1.15.0)
# Building wheels for collected packages: torchsampler
#   Building wheel for torchsampler (setup.py) ... done
#   Created wheel for torchsampler: filename=torchsampler-0.1.1-cp37-none-any.whl size=3827 sha256=c450aab6e5ed191ae36eb769b02110e2522c27e0d759a97bb42df44ea36e7409
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nqjgw_jk/wheels/c1/f1/dc/587588aa0a5f0dc76673d98a554ff4db2575aaca3984240ec1
# Successfully built torchsampler
# Installing collected packages: torchsampler
# Successfully installed torchsampler-0.1.1

# %%
import torch, torchvision
import torchvision.transforms as transforms
transform = transforms.Compose([ transforms.ToPILImage(), 
                                transforms.Resize((224,224)),
                                transforms.CenterCrop(120),
                                transforms.ToTensor(),
                                transforms.Normalize(mean=[0.4681, 0.4030, 0.5275] , std =[1.5016, 1.5685, 1.5956])])

# %%
import torch
from torch.utils.data import Dataset
import pandas as pd
from torchvision.io import read_image

class RAF_Dataset(Dataset):

  def __init__(self,csv_file,root_dir,transform=None):

    self.annotations = pd.read_csv(csv_file)
    self.root_dir = root_dir
    self.transform = transform

  def __len__(self):
    return len(self.annotations)

  def __getitem__(self,idx):
    img_path = os.path.join(self.root_dir,self.annotations.iloc[idx,1])
    image = read_image(img_path)
    label = torch.tensor(int(self.annotations.iloc[idx,2]))

    if self.transform:
      image = self.transform(image)

      return(image,label)

# %%
train_set = RAF_Dataset ( csv_file = '/content/drive/MyDrive/Single Emotions (1)/Train_set/train_labels.csv' , 
                         root_dir = '/content/drive/MyDrive/Single Emotions (1)/Train_set/Train' ,
                         transform = transform)
len(train_set)
# Out:
# 12271

# %%
class_count = [1290 , 281 , 717 , 4772 , 1982 ,705 , 2524]
class_weight = 1./ torch.tensor(class_count , dtype = torch.float)
class_weight

#from torch.utils.data import WeightedRandomSampler
#weight_sampler = WeightedRandomSampler(weights = class_weight , num_samples = 12271 , replacement = True)
# Out:
# tensor([0.0008, 0.0036, 0.0014, 0.0002, 0.0005, 0.0014, 0.0004])

# %%
from torch.utils.data.sampler import WeightedRandomSampler

counts = [1290.0, 281.0 ,717.0 , 4772.0 , 1982.0 , 705.0 , 2524.0 ]
label_weights = 
print(label_weights)
y = [0, 1,2,3,4,5,6]
weights = label_weights[y]
sapler = WeightedRandomSampler(weights, 64, replacement = True)
# Out:
# tensor([0.0008, 0.0036, 0.0014, 0.0002, 0.0005, 0.0014, 0.0004])

# %%
import matplotlib.pyplot as plt
sample = train_set[9570][0].numpy().transpose(1,2,0)
plt.imshow(sample)
print(train_set [0][1])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# tensor(4)

# %%
train_loaders = torch.utils.data.DataLoader(train_set, batch_size=64, shuffle=True )

# %%
images,labels = next(iter(train_loaders))
labels
# Out:
# tensor([0, 6, 6, 3, 4, 5, 2, 6, 2, 6, 3, 3, 0, 5, 3, 4, 2, 0, 6, 6, 0, 6, 6, 3,
#         3, 1, 3, 3, 4, 6, 3, 3, 3, 0, 6, 4, 3, 3, 5, 3, 0, 0, 6, 4, 0, 6, 6, 3,
#         6, 3, 3, 3, 6, 2, 0, 3, 6, 6, 3, 2, 3, 3, 6, 3])

# %%
import matplotlib.pyplot as plt

grid = torchvision.utils.make_grid(images , nrows = 1)
sample = grid.numpy().transpose(1,2,0)
plt.figure(figsize=(15,15))
plt.imshow(sample)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
device = torch.device ('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
import torch.nn as nn

model = torchvision.models.resnet101(pretrained = True)
model.fc = nn.Sequential(nn.Linear(model.fc.in_features,500),nn.ReLU(),nn.Dropout(),nn.Linear(500,7))
print(model)
optim = torch.optim.Adam(model.parameters() , lr = 1e-4)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=500, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=500, out_features=7, bias=True)
#   )
# )

# %%
crit = nn.CrossEntropyLoss( )
scalar = torch.cuda.amp.GradScaler()

# %%
num_epochs = 50
total_step = len(train_loaders)

losses = []
train_accuracy = []


for epoch in range(num_epochs):
  for i, (images,labels) in enumerate(train_loaders):
        images = images.to(device)
        labels = labels.to(device)
        model = model.to(device)
        optim.zero_grad()
        with torch.cuda.amp.autocast():

          outputs = model(images)
          loss = crit(outputs, labels)
        
        
        loss.backward()
        optim.step()

        _, argmax = torch.max(outputs, 1)
        accuracy = (labels == argmax.squeeze()).float().mean()

        losses.append(loss.item()/ total_step)
        train_accuracy .append(accuracy.item())

        if (i+1) % 37 == 1:
            print ('Epoch [{}/{}], Step [{}/{}], Log_Loss: {:.4f} , Accuracy at the step {:.3f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item() , accuracy.item() ))
# Out:
# Epoch [1/50], Step [1/192], Log_Loss: 2.0036 , Accuracy at the step 0.062
# Epoch [1/50], Step [38/192], Log_Loss: 1.4312 , Accuracy at the step 0.438
# Epoch [1/50], Step [75/192], Log_Loss: 0.9191 , Accuracy at the step 0.688
# Epoch [1/50], Step [112/192], Log_Loss: 0.9780 , Accuracy at the step 0.641
# Epoch [1/50], Step [149/192], Log_Loss: 0.8185 , Accuracy at the step 0.641
# Epoch [1/50], Step [186/192], Log_Loss: 0.7464 , Accuracy at the step 0.750
# Epoch [2/50], Step [1/192], Log_Loss: 0.8051 , Accuracy at the step 0.734
# Epoch [2/50], Step [38/192], Log_Loss: 0.8431 , Accuracy at the step 0.781
# Epoch [2/50], Step [75/192], Log_Loss: 0.5009 , Accuracy at the step 0.812
# Epoch [2/50], Step [112/192], Log_Loss: 0.6378 , Accuracy at the step 0.797
# Epoch [2/50], Step [149/192], Log_Loss: 0.8230 , Accuracy at the step 0.734
# Epoch [2/50], Step [186/192], Log_Loss: 0.6825 , Accuracy at the step 0.797
# Epoch [3/50], Step [1/192], Log_Loss: 0.3308 , Accuracy at the step 0.875
# Epoch [3/50], Step [38/192], Log_Loss: 0.1573 , Accuracy at the step 0.953
# Epoch [3/50], Step [75/192], Log_Loss: 0.2028 , Accuracy at the step 0.953
# Epoch [3/50], Step [112/192], Log_Loss: 0.2648 , Accuracy at the step 0.922
# Epoch [3/50], Step [149/192], Log_Loss: 0.2974 , Accuracy at the step 0.906
# Epoch [3/50], Step [186/192], Log_Loss: 0.3390 , Accuracy at the step 0.906
# Epoch [4/50], Step [1/192], Log_Loss: 0.1741 , Accuracy at the step 0.906
# Epoch [4/50], Step [38/192], Log_Loss: 0.1988 , Accuracy at the step 0.953
# Epoch [4/50], Step [75/192], Log_Loss: 0.0862 , Accuracy at the step 0.953
# Epoch [4/50], Step [112/192], Log_Loss: 0.1696 , Accuracy at the step 0.938
# Epoch [4/50], Step [149/192], Log_Loss: 0.4730 , Accuracy at the step 0.859
# Epoch [4/50], Step [186/192], Log_Loss: 0.1028 , Accuracy at the step 0.969
# Epoch [5/50], Step [1/192], Log_Loss: 0.0314 , Accuracy at the step 1.000
# Epoch [5/50], Step [38/192], Log_Loss: 0.0311 , Accuracy at the step 0.984
# Epoch [5/50], Step [75/192], Log_Loss: 0.0246 , Accuracy at the step 1.000
# Epoch [5/50], Step [112/192], Log_Loss: 0.0303 , Accuracy at the step 1.000
# Epoch [5/50], Step [149/192], Log_Loss: 0.1774 , Accuracy at the step 0.938
# Epoch [5/50], Step [186/192], Log_Loss: 0.0788 , Accuracy at the step 0.969
# Epoch [6/50], Step [1/192], Log_Loss: 0.0419 , Accuracy at the step 0.984
# Epoch [6/50], Step [38/192], Log_Loss: 0.0783 , Accuracy at the step 0.984
# Epoch [6/50], Step [75/192], Log_Loss: 0.2786 , Accuracy at the step 0.922
# Epoch [6/50], Step [112/192], Log_Loss: 0.1106 , Accuracy at the step 0.953
# Epoch [6/50], Step [149/192], Log_Loss: 0.1584 , Accuracy at the step 0.938
# Epoch [6/50], Step [186/192], Log_Loss: 0.0531 , Accuracy at the step 0.984
# Epoch [7/50], Step [1/192], Log_Loss: 0.0922 , Accuracy at the step 0.984
# Epoch [7/50], Step [38/192], Log_Loss: 0.0616 , Accuracy at the step 0.984
# Epoch [7/50], Step [75/192], Log_Loss: 0.0571 , Accuracy at the step 0.984
# Epoch [7/50], Step [112/192], Log_Loss: 0.0436 , Accuracy at the step 0.984
# Epoch [7/50], Step [149/192], Log_Loss: 0.0428 , Accuracy at the step 0.969
# Epoch [7/50], Step [186/192], Log_Loss: 0.0383 , Accuracy at the step 0.984
# Epoch [8/50], Step [1/192], Log_Loss: 0.0250 , Accuracy at the step 1.000
# Epoch [8/50], Step [38/192], Log_Loss: 0.0689 , Accuracy at the step 0.953
# Epoch [8/50], Step [75/192], Log_Loss: 0.0062 , Accuracy at the step 1.000
# Epoch [8/50], Step [112/192], Log_Loss: 0.1149 , Accuracy at the step 0.938
# Epoch [8/50], Step [149/192], Log_Loss: 0.0197 , Accuracy at the step 1.000
# Epoch [8/50], Step [186/192], Log_Loss: 0.0468 , Accuracy at the step 0.984
# Epoch [9/50], Step [1/192], Log_Loss: 0.0063 , Accuracy at the step 1.000
# Epoch [9/50], Step [38/192], Log_Loss: 0.0339 , Accuracy at the step 1.000
# Epoch [9/50], Step [75/192], Log_Loss: 0.0668 , Accuracy at the step 0.969
# Epoch [9/50], Step [112/192], Log_Loss: 0.0573 , Accuracy at the step 0.984
# Epoch [9/50], Step [149/192], Log_Loss: 0.0764 , Accuracy at the step 0.984
# Epoch [9/50], Step [186/192], Log_Loss: 0.0224 , Accuracy at the step 1.000
# Epoch [10/50], Step [1/192], Log_Loss: 0.0169 , Accuracy at the step 1.000
# Epoch [10/50], Step [38/192], Log_Loss: 0.0745 , Accuracy at the step 0.984
# Epoch [10/50], Step [75/192], Log_Loss: 0.1027 , Accuracy at the step 0.953
# Epoch [10/50], Step [112/192], Log_Loss: 0.0350 , Accuracy at the step 0.984
# Epoch [10/50], Step [149/192], Log_Loss: 0.0093 , Accuracy at the step 1.000
# Epoch [10/50], Step [186/192], Log_Loss: 0.1828 , Accuracy at the step 0.984
# Epoch [11/50], Step [1/192], Log_Loss: 0.0127 , Accuracy at the step 1.000
# Epoch [11/50], Step [38/192], Log_Loss: 0.0064 , Accuracy at the step 1.000
# Epoch [11/50], Step [75/192], Log_Loss: 0.0112 , Accuracy at the step 1.000
# Epoch [11/50], Step [112/192], Log_Loss: 0.0306 , Accuracy at the step 1.000
# Epoch [11/50], Step [149/192], Log_Loss: 0.1097 , Accuracy at the step 0.969
# Epoch [11/50], Step [186/192], Log_Loss: 0.0372 , Accuracy at the step 0.984
# Epoch [12/50], Step [1/192], Log_Loss: 0.0893 , Accuracy at the step 0.984
# Epoch [12/50], Step [38/192], Log_Loss: 0.0061 , Accuracy at the step 1.000
# Epoch [12/50], Step [75/192], Log_Loss: 0.0303 , Accuracy at the step 0.984
# Epoch [12/50], Step [112/192], Log_Loss: 0.0209 , Accuracy at the step 1.000
# Epoch [12/50], Step [149/192], Log_Loss: 0.0061 , Accuracy at the step 1.000
# Epoch [12/50], Step [186/192], Log_Loss: 0.0047 , Accuracy at the step 1.000
# Epoch [13/50], Step [1/192], Log_Loss: 0.0186 , Accuracy at the step 1.000
# Epoch [13/50], Step [38/192], Log_Loss: 0.0705 , Accuracy at the step 0.984
# Epoch [13/50], Step [75/192], Log_Loss: 0.0129 , Accuracy at the step 1.000
# Epoch [13/50], Step [112/192], Log_Loss: 0.0066 , Accuracy at the step 1.000
# Epoch [13/50], Step [149/192], Log_Loss: 0.0287 , Accuracy at the step 0.984
# Epoch [13/50], Step [186/192], Log_Loss: 0.0692 , Accuracy at the step 0.984
# Epoch [14/50], Step [1/192], Log_Loss: 0.0656 , Accuracy at the step 0.984
# Epoch [14/50], Step [38/192], Log_Loss: 0.0556 , Accuracy at the step 0.969
# Epoch [14/50], Step [75/192], Log_Loss: 0.3303 , Accuracy at the step 0.969
# Epoch [14/50], Step [112/192], Log_Loss: 0.0881 , Accuracy at the step 0.984
# Epoch [14/50], Step [149/192], Log_Loss: 0.0201 , Accuracy at the step 1.000
# Epoch [14/50], Step [186/192], Log_Loss: 0.0834 , Accuracy at the step 0.953
# Epoch [15/50], Step [1/192], Log_Loss: 0.0620 , Accuracy at the step 0.969
# Epoch [15/50], Step [38/192], Log_Loss: 0.0576 , Accuracy at the step 0.984
# Epoch [15/50], Step [75/192], Log_Loss: 0.0543 , Accuracy at the step 0.953
# Epoch [15/50], Step [112/192], Log_Loss: 0.0089 , Accuracy at the step 1.000
# Epoch [15/50], Step [149/192], Log_Loss: 0.0410 , Accuracy at the step 0.984
# Epoch [15/50], Step [186/192], Log_Loss: 0.0108 , Accuracy at the step 1.000
# Epoch [16/50], Step [1/192], Log_Loss: 0.0971 , Accuracy at the step 0.984
# Epoch [16/50], Step [38/192], Log_Loss: 0.1180 , Accuracy at the step 0.984
# Epoch [16/50], Step [75/192], Log_Loss: 0.0055 , Accuracy at the step 1.000
# Epoch [16/50], Step [112/192], Log_Loss: 0.0095 , Accuracy at the step 1.000
# Epoch [16/50], Step [149/192], Log_Loss: 0.0599 , Accuracy at the step 0.984
# Epoch [16/50], Step [186/192], Log_Loss: 0.0506 , Accuracy at the step 0.984
# Epoch [17/50], Step [1/192], Log_Loss: 0.0531 , Accuracy at the step 0.984
# Epoch [17/50], Step [38/192], Log_Loss: 0.0576 , Accuracy at the step 0.984
# Epoch [17/50], Step [75/192], Log_Loss: 0.0875 , Accuracy at the step 0.984
# Epoch [17/50], Step [112/192], Log_Loss: 0.0241 , Accuracy at the step 0.984
# Epoch [17/50], Step [149/192], Log_Loss: 0.0011 , Accuracy at the step 1.000
# Epoch [17/50], Step [186/192], Log_Loss: 0.0017 , Accuracy at the step 1.000
# Epoch [18/50], Step [1/192], Log_Loss: 0.0084 , Accuracy at the step 1.000
# Epoch [18/50], Step [38/192], Log_Loss: 0.0146 , Accuracy at the step 0.984
# Epoch [18/50], Step [75/192], Log_Loss: 0.0053 , Accuracy at the step 1.000
# Epoch [18/50], Step [112/192], Log_Loss: 0.1377 , Accuracy at the step 0.969
# Epoch [18/50], Step [149/192], Log_Loss: 0.0040 , Accuracy at the step 1.000
# Epoch [18/50], Step [186/192], Log_Loss: 0.0061 , Accuracy at the step 1.000
# Epoch [19/50], Step [1/192], Log_Loss: 0.0167 , Accuracy at the step 1.000
# Epoch [19/50], Step [38/192], Log_Loss: 0.0212 , Accuracy at the step 0.984
# Epoch [19/50], Step [75/192], Log_Loss: 0.0011 , Accuracy at the step 1.000
# Epoch [19/50], Step [112/192], Log_Loss: 0.0556 , Accuracy at the step 0.984
# Epoch [19/50], Step [149/192], Log_Loss: 0.1054 , Accuracy at the step 0.969
# Epoch [19/50], Step [186/192], Log_Loss: 0.0034 , Accuracy at the step 1.000
# Epoch [20/50], Step [1/192], Log_Loss: 0.0011 , Accuracy at the step 1.000
# Epoch [20/50], Step [38/192], Log_Loss: 0.0281 , Accuracy at the step 0.984
# Epoch [20/50], Step [75/192], Log_Loss: 0.0373 , Accuracy at the step 0.984
# Epoch [20/50], Step [112/192], Log_Loss: 0.0022 , Accuracy at the step 1.000
# Epoch [20/50], Step [149/192], Log_Loss: 0.0547 , Accuracy at the step 0.984
# Epoch [20/50], Step [186/192], Log_Loss: 0.0080 , Accuracy at the step 1.000
# Epoch [21/50], Step [1/192], Log_Loss: 0.0420 , Accuracy at the step 0.984
# Epoch [21/50], Step [38/192], Log_Loss: 0.0013 , Accuracy at the step 1.000
# Epoch [21/50], Step [75/192], Log_Loss: 0.0144 , Accuracy at the step 1.000
# Epoch [21/50], Step [112/192], Log_Loss: 0.0063 , Accuracy at the step 1.000
# Epoch [21/50], Step [149/192], Log_Loss: 0.0095 , Accuracy at the step 1.000
# Epoch [21/50], Step [186/192], Log_Loss: 0.0232 , Accuracy at the step 0.984
# Epoch [22/50], Step [1/192], Log_Loss: 0.0053 , Accuracy at the step 1.000
# Epoch [22/50], Step [38/192], Log_Loss: 0.0030 , Accuracy at the step 1.000
# Epoch [22/50], Step [75/192], Log_Loss: 0.0117 , Accuracy at the step 1.000
# Epoch [22/50], Step [112/192], Log_Loss: 0.0507 , Accuracy at the step 0.984
# Epoch [22/50], Step [149/192], Log_Loss: 0.0231 , Accuracy at the step 1.000
# Epoch [22/50], Step [186/192], Log_Loss: 0.0215 , Accuracy at the step 0.984
# Epoch [23/50], Step [1/192], Log_Loss: 0.0320 , Accuracy at the step 0.984
# Epoch [23/50], Step [38/192], Log_Loss: 0.0362 , Accuracy at the step 0.984
# Epoch [23/50], Step [75/192], Log_Loss: 0.0034 , Accuracy at the step 1.000
# Epoch [23/50], Step [112/192], Log_Loss: 0.0376 , Accuracy at the step 0.984
# Epoch [23/50], Step [149/192], Log_Loss: 0.0042 , Accuracy at the step 1.000
# Epoch [23/50], Step [186/192], Log_Loss: 0.0100 , Accuracy at the step 1.000
# Epoch [24/50], Step [1/192], Log_Loss: 0.0515 , Accuracy at the step 0.969
# Epoch [24/50], Step [38/192], Log_Loss: 0.0046 , Accuracy at the step 1.000
# Epoch [24/50], Step [75/192], Log_Loss: 0.0154 , Accuracy at the step 0.984
# Epoch [24/50], Step [112/192], Log_Loss: 0.0118 , Accuracy at the step 1.000
# Epoch [24/50], Step [149/192], Log_Loss: 0.0187 , Accuracy at the step 1.000
# Epoch [24/50], Step [186/192], Log_Loss: 0.0494 , Accuracy at the step 0.984
# Epoch [25/50], Step [1/192], Log_Loss: 0.0014 , Accuracy at the step 1.000
# Epoch [25/50], Step [38/192], Log_Loss: 0.0132 , Accuracy at the step 1.000
# Epoch [25/50], Step [75/192], Log_Loss: 0.0183 , Accuracy at the step 0.984
# Epoch [25/50], Step [112/192], Log_Loss: 0.0015 , Accuracy at the step 1.000
# Epoch [25/50], Step [149/192], Log_Loss: 0.0040 , Accuracy at the step 1.000
# Epoch [25/50], Step [186/192], Log_Loss: 0.0045 , Accuracy at the step 1.000
# Epoch [26/50], Step [1/192], Log_Loss: 0.0061 , Accuracy at the step 1.000
# Epoch [26/50], Step [38/192], Log_Loss: 0.0122 , Accuracy at the step 1.000
# Epoch [26/50], Step [75/192], Log_Loss: 0.0157 , Accuracy at the step 1.000
# Epoch [26/50], Step [112/192], Log_Loss: 0.0116 , Accuracy at the step 1.000
# Epoch [26/50], Step [149/192], Log_Loss: 0.0156 , Accuracy at the step 1.000
# Epoch [26/50], Step [186/192], Log_Loss: 0.0224 , Accuracy at the step 1.000
# Epoch [27/50], Step [1/192], Log_Loss: 0.0025 , Accuracy at the step 1.000
# Epoch [27/50], Step [38/192], Log_Loss: 0.1492 , Accuracy at the step 0.953
# Epoch [27/50], Step [75/192], Log_Loss: 0.0556 , Accuracy at the step 0.969
# Epoch [27/50], Step [112/192], Log_Loss: 0.0464 , Accuracy at the step 0.984
# Epoch [27/50], Step [149/192], Log_Loss: 0.0028 , Accuracy at the step 1.000
# Epoch [27/50], Step [186/192], Log_Loss: 0.0262 , Accuracy at the step 0.984
# Epoch [28/50], Step [1/192], Log_Loss: 0.0034 , Accuracy at the step 1.000
# Epoch [28/50], Step [38/192], Log_Loss: 0.0097 , Accuracy at the step 1.000
# Epoch [28/50], Step [75/192], Log_Loss: 0.0050 , Accuracy at the step 1.000
# Epoch [28/50], Step [112/192], Log_Loss: 0.0280 , Accuracy at the step 0.984
# Epoch [28/50], Step [149/192], Log_Loss: 0.0008 , Accuracy at the step 1.000
# Epoch [28/50], Step [186/192], Log_Loss: 0.1636 , Accuracy at the step 0.969
# Epoch [29/50], Step [1/192], Log_Loss: 0.0129 , Accuracy at the step 1.000
# Epoch [29/50], Step [38/192], Log_Loss: 0.0259 , Accuracy at the step 0.984
# Epoch [29/50], Step [75/192], Log_Loss: 0.0038 , Accuracy at the step 1.000
# Epoch [29/50], Step [112/192], Log_Loss: 0.0077 , Accuracy at the step 1.000
# Epoch [29/50], Step [149/192], Log_Loss: 0.0021 , Accuracy at the step 1.000
# Epoch [29/50], Step [186/192], Log_Loss: 0.0466 , Accuracy at the step 0.984
# Epoch [30/50], Step [1/192], Log_Loss: 0.0092 , Accuracy at the step 1.000
# Epoch [30/50], Step [38/192], Log_Loss: 0.0073 , Accuracy at the step 1.000
# Epoch [30/50], Step [75/192], Log_Loss: 0.1144 , Accuracy at the step 0.984
# Epoch [30/50], Step [112/192], Log_Loss: 0.0400 , Accuracy at the step 0.984
# Epoch [30/50], Step [149/192], Log_Loss: 0.0075 , Accuracy at the step 1.000
# Epoch [30/50], Step [186/192], Log_Loss: 0.0953 , Accuracy at the step 0.969
# Epoch [31/50], Step [1/192], Log_Loss: 0.0027 , Accuracy at the step 1.000
# Epoch [31/50], Step [38/192], Log_Loss: 0.0024 , Accuracy at the step 1.000
# Epoch [31/50], Step [75/192], Log_Loss: 0.0118 , Accuracy at the step 1.000
# Epoch [31/50], Step [112/192], Log_Loss: 0.0253 , Accuracy at the step 0.984
# Epoch [31/50], Step [149/192], Log_Loss: 0.0076 , Accuracy at the step 1.000
# Epoch [31/50], Step [186/192], Log_Loss: 0.0025 , Accuracy at the step 1.000
# Epoch [32/50], Step [1/192], Log_Loss: 0.0180 , Accuracy at the step 0.984
# Epoch [32/50], Step [38/192], Log_Loss: 0.0151 , Accuracy at the step 1.000
# Epoch [32/50], Step [75/192], Log_Loss: 0.0007 , Accuracy at the step 1.000
# Epoch [32/50], Step [112/192], Log_Loss: 0.0089 , Accuracy at the step 1.000
# Epoch [32/50], Step [149/192], Log_Loss: 0.0827 , Accuracy at the step 0.969
# Epoch [32/50], Step [186/192], Log_Loss: 0.1047 , Accuracy at the step 0.984
# Epoch [33/50], Step [1/192], Log_Loss: 0.0327 , Accuracy at the step 0.984
# Epoch [33/50], Step [38/192], Log_Loss: 0.0002 , Accuracy at the step 1.000
# Epoch [33/50], Step [75/192], Log_Loss: 0.0016 , Accuracy at the step 1.000
# Epoch [33/50], Step [112/192], Log_Loss: 0.0002 , Accuracy at the step 1.000
# Epoch [33/50], Step [149/192], Log_Loss: 0.0507 , Accuracy at the step 0.984
# Epoch [33/50], Step [186/192], Log_Loss: 0.0002 , Accuracy at the step 1.000
# Epoch [34/50], Step [1/192], Log_Loss: 0.0082 , Accuracy at the step 1.000
# Epoch [34/50], Step [38/192], Log_Loss: 0.0050 , Accuracy at the step 1.000
# Epoch [34/50], Step [75/192], Log_Loss: 0.0040 , Accuracy at the step 1.000
# Epoch [34/50], Step [112/192], Log_Loss: 0.0008 , Accuracy at the step 1.000
# Epoch [34/50], Step [149/192], Log_Loss: 0.0013 , Accuracy at the step 1.000
# Epoch [34/50], Step [186/192], Log_Loss: 0.0044 , Accuracy at the step 1.000
# Epoch [35/50], Step [1/192], Log_Loss: 0.1033 , Accuracy at the step 0.969
# Epoch [35/50], Step [38/192], Log_Loss: 0.0118 , Accuracy at the step 1.000
# Epoch [35/50], Step [75/192], Log_Loss: 0.0425 , Accuracy at the step 0.984
# Epoch [35/50], Step [112/192], Log_Loss: 0.0887 , Accuracy at the step 0.969
# Epoch [35/50], Step [149/192], Log_Loss: 0.0041 , Accuracy at the step 1.000
# Epoch [35/50], Step [186/192], Log_Loss: 0.0075 , Accuracy at the step 1.000
# Epoch [36/50], Step [1/192], Log_Loss: 0.0079 , Accuracy at the step 1.000
# Epoch [36/50], Step [38/192], Log_Loss: 0.0044 , Accuracy at the step 1.000
# Epoch [36/50], Step [75/192], Log_Loss: 0.0114 , Accuracy at the step 1.000
# Epoch [36/50], Step [112/192], Log_Loss: 0.0613 , Accuracy at the step 0.984
# Epoch [36/50], Step [149/192], Log_Loss: 0.0017 , Accuracy at the step 1.000
# Epoch [36/50], Step [186/192], Log_Loss: 0.0808 , Accuracy at the step 0.969
# Epoch [37/50], Step [1/192], Log_Loss: 0.0016 , Accuracy at the step 1.000
# Epoch [37/50], Step [38/192], Log_Loss: 0.0116 , Accuracy at the step 1.000
# Epoch [37/50], Step [75/192], Log_Loss: 0.0007 , Accuracy at the step 1.000
# Epoch [37/50], Step [112/192], Log_Loss: 0.0431 , Accuracy at the step 0.984
# Epoch [37/50], Step [149/192], Log_Loss: 0.0081 , Accuracy at the step 1.000
# Epoch [37/50], Step [186/192], Log_Loss: 0.0010 , Accuracy at the step 1.000
# Epoch [38/50], Step [1/192], Log_Loss: 0.0132 , Accuracy at the step 0.984
# Epoch [38/50], Step [38/192], Log_Loss: 0.0017 , Accuracy at the step 1.000
# Epoch [38/50], Step [75/192], Log_Loss: 0.0007 , Accuracy at the step 1.000
# Epoch [38/50], Step [112/192], Log_Loss: 0.0117 , Accuracy at the step 1.000
# Epoch [38/50], Step [149/192], Log_Loss: 0.0137 , Accuracy at the step 1.000
# Epoch [38/50], Step [186/192], Log_Loss: 0.0034 , Accuracy at the step 1.000
# Epoch [39/50], Step [1/192], Log_Loss: 0.0057 , Accuracy at the step 1.000
# Epoch [39/50], Step [38/192], Log_Loss: 0.0144 , Accuracy at the step 0.984
# Epoch [39/50], Step [75/192], Log_Loss: 0.0007 , Accuracy at the step 1.000
# Epoch [39/50], Step [112/192], Log_Loss: 0.0215 , Accuracy at the step 0.984
# Epoch [39/50], Step [149/192], Log_Loss: 0.0029 , Accuracy at the step 1.000
# Epoch [39/50], Step [186/192], Log_Loss: 0.0012 , Accuracy at the step 1.000
# Epoch [40/50], Step [1/192], Log_Loss: 0.0007 , Accuracy at the step 1.000
# Epoch [40/50], Step [38/192], Log_Loss: 0.0008 , Accuracy at the step 1.000
# Epoch [40/50], Step [75/192], Log_Loss: 0.0003 , Accuracy at the step 1.000
# Epoch [40/50], Step [112/192], Log_Loss: 0.0029 , Accuracy at the step 1.000
# Epoch [40/50], Step [149/192], Log_Loss: 0.0006 , Accuracy at the step 1.000
# Epoch [40/50], Step [186/192], Log_Loss: 0.0005 , Accuracy at the step 1.000
# Epoch [41/50], Step [1/192], Log_Loss: 0.0004 , Accuracy at the step 1.000
# Epoch [41/50], Step [38/192], Log_Loss: 0.0008 , Accuracy at the step 1.000
# Epoch [41/50], Step [75/192], Log_Loss: 0.0006 , Accuracy at the step 1.000
# Epoch [41/50], Step [112/192], Log_Loss: 0.0036 , Accuracy at the step 1.000
# Epoch [41/50], Step [149/192], Log_Loss: 0.0157 , Accuracy at the step 1.000
# Epoch [41/50], Step [186/192], Log_Loss: 0.0770 , Accuracy at the step 0.953
# Epoch [42/50], Step [1/192], Log_Loss: 0.0153 , Accuracy at the step 1.000
# Epoch [42/50], Step [38/192], Log_Loss: 0.0481 , Accuracy at the step 0.984
# Epoch [42/50], Step [75/192], Log_Loss: 0.0064 , Accuracy at the step 1.000
# Epoch [42/50], Step [112/192], Log_Loss: 0.0236 , Accuracy at the step 0.984
# Epoch [42/50], Step [149/192], Log_Loss: 0.0040 , Accuracy at the step 1.000
# Epoch [42/50], Step [186/192], Log_Loss: 0.0042 , Accuracy at the step 1.000
# Epoch [43/50], Step [1/192], Log_Loss: 0.0014 , Accuracy at the step 1.000
# Epoch [43/50], Step [38/192], Log_Loss: 0.0028 , Accuracy at the step 1.000
# Epoch [43/50], Step [75/192], Log_Loss: 0.0903 , Accuracy at the step 0.969
# Epoch [43/50], Step [112/192], Log_Loss: 0.0171 , Accuracy at the step 0.984
# Epoch [43/50], Step [149/192], Log_Loss: 0.0298 , Accuracy at the step 1.000
# Epoch [43/50], Step [186/192], Log_Loss: 0.0213 , Accuracy at the step 1.000
# Epoch [44/50], Step [1/192], Log_Loss: 0.1059 , Accuracy at the step 0.969
# Epoch [44/50], Step [38/192], Log_Loss: 0.0623 , Accuracy at the step 0.953
# Epoch [44/50], Step [75/192], Log_Loss: 0.0048 , Accuracy at the step 1.000
# Epoch [44/50], Step [112/192], Log_Loss: 0.0934 , Accuracy at the step 0.984
# Epoch [44/50], Step [149/192], Log_Loss: 0.0073 , Accuracy at the step 1.000
# Epoch [44/50], Step [186/192], Log_Loss: 0.0505 , Accuracy at the step 0.984
# Epoch [45/50], Step [1/192], Log_Loss: 0.0007 , Accuracy at the step 1.000
# Epoch [45/50], Step [38/192], Log_Loss: 0.0027 , Accuracy at the step 1.000
# Epoch [45/50], Step [75/192], Log_Loss: 0.0007 , Accuracy at the step 1.000
# Epoch [45/50], Step [112/192], Log_Loss: 0.0040 , Accuracy at the step 1.000
# Epoch [45/50], Step [149/192], Log_Loss: 0.0066 , Accuracy at the step 1.000
# Epoch [45/50], Step [186/192], Log_Loss: 0.0073 , Accuracy at the step 1.000
# Epoch [46/50], Step [1/192], Log_Loss: 0.0177 , Accuracy at the step 1.000
# Epoch [46/50], Step [38/192], Log_Loss: 0.0044 , Accuracy at the step 1.000
# Epoch [46/50], Step [75/192], Log_Loss: 0.0107 , Accuracy at the step 1.000
# Epoch [46/50], Step [112/192], Log_Loss: 0.0024 , Accuracy at the step 1.000
# Epoch [46/50], Step [149/192], Log_Loss: 0.0154 , Accuracy at the step 1.000
# Epoch [46/50], Step [186/192], Log_Loss: 0.0802 , Accuracy at the step 0.969
# Epoch [47/50], Step [1/192], Log_Loss: 0.0064 , Accuracy at the step 1.000
# Epoch [47/50], Step [38/192], Log_Loss: 0.0151 , Accuracy at the step 1.000
# Epoch [47/50], Step [75/192], Log_Loss: 0.0152 , Accuracy at the step 1.000
# Epoch [47/50], Step [112/192], Log_Loss: 0.0031 , Accuracy at the step 1.000
# Epoch [47/50], Step [149/192], Log_Loss: 0.0001 , Accuracy at the step 1.000
# Epoch [47/50], Step [186/192], Log_Loss: 0.0026 , Accuracy at the step 1.000
# Epoch [48/50], Step [1/192], Log_Loss: 0.0694 , Accuracy at the step 0.969
# Epoch [48/50], Step [38/192], Log_Loss: 0.0076 , Accuracy at the step 1.000
# Epoch [48/50], Step [75/192], Log_Loss: 0.0311 , Accuracy at the step 0.969
# Epoch [48/50], Step [112/192], Log_Loss: 0.0013 , Accuracy at the step 1.000
# Epoch [48/50], Step [149/192], Log_Loss: 0.0883 , Accuracy at the step 0.953
# Epoch [48/50], Step [186/192], Log_Loss: 0.0047 , Accuracy at the step 1.000
# Epoch [49/50], Step [1/192], Log_Loss: 0.0052 , Accuracy at the step 1.000
# Epoch [49/50], Step [38/192], Log_Loss: 0.0142 , Accuracy at the step 0.984
# Epoch [49/50], Step [75/192], Log_Loss: 0.0509 , Accuracy at the step 0.984
# Epoch [49/50], Step [112/192], Log_Loss: 0.0188 , Accuracy at the step 0.984
# Epoch [49/50], Step [149/192], Log_Loss: 0.0176 , Accuracy at the step 0.984
# Epoch [49/50], Step [186/192], Log_Loss: 0.0011 , Accuracy at the step 1.000
# Epoch [50/50], Step [1/192], Log_Loss: 0.0014 , Accuracy at the step 1.000
# Epoch [50/50], Step [38/192], Log_Loss: 0.0008 , Accuracy at the step 1.000
# Epoch [50/50], Step [75/192], Log_Loss: 0.0002 , Accuracy at the step 1.000
# Epoch [50/50], Step [112/192], Log_Loss: 0.0022 , Accuracy at the step 1.000
# Epoch [50/50], Step [149/192], Log_Loss: 0.0060 , Accuracy at the step 1.000
# Epoch [50/50], Step [186/192], Log_Loss: 0.0701 , Accuracy at the step 0.969

# %%
import matplotlib.pyplot as plt
plt.plot(losses)
plt.title("Loss Curve (batch_size = 64 , lr = 0.0001)")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.show()


plt.plot(train_accuracy)
plt.title("Training Curve (batch_size = 64 , lr= 0.0001")
plt.xlabel("Steps")
plt.ylabel("Training Accuracy")
plt.show()

# %%
test_set = RAF_Dataset ( csv_file = '/content/drive/MyDrive/Single Emotions (1)/Test_set/test_labels.csv' , 
                         root_dir = '/content/drive/MyDrive/Single Emotions (1)/Test_set/Test' ,
                         transform = transform)

test_loaders = torch.utils.data.DataLoader(test_set, batch_size=64,shuffle=False )

# %%
model.eval()  
with torch.no_grad():
    correct = 0
    total = 0
    for images1, labels1 in test_loaders:
        images1 = images1.to(device)
        labels1 = labels1.to(device)
        model = model.to(device)
        outputs1 = model(images1)
        _, predicted = torch.max(outputs1.data, 1)
        total += labels1.size(0)
        correct += (predicted == labels1).sum().item()
    
    print('Accuracy of model is : {} %' .format(100*correct/total))
# Out:
# Accuracy of model is : 78.74837027379401 %

# %%
nb_classes = 7

confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for i, (images, labels) in enumerate(test_loaders):
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(labels.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

print(confusion_matrix)
print(confusion_matrix.diag()/confusion_matrix.sum(1))
# Out:
# tensor([[2.6600e+02, 5.0000e+00, 6.0000e+00, 1.5000e+01, 8.0000e+00, 5.0000e+00,
#          2.4000e+01],
#         [1.3000e+01, 3.3000e+01, 0.0000e+00, 8.0000e+00, 6.0000e+00, 7.0000e+00,
#          7.0000e+00],
#         [9.0000e+00, 2.0000e+00, 4.4000e+01, 1.5000e+01, 2.6000e+01, 1.3000e+01,
#          5.1000e+01],
#         [1.3000e+01, 1.0000e+00, 5.0000e+00, 1.0670e+03, 3.2000e+01, 9.0000e+00,
#          5.8000e+01],
#         [8.0000e+00, 2.0000e+00, 8.0000e+00, 2.0000e+01, 3.7400e+02, 9.0000e+00,
#          5.7000e+01],
#         [1.0000e+01, 3.0000e+00, 5.0000e+00, 1.4000e+01, 5.0000e+00, 1.1000e+02,
#          1.5000e+01],
#         [4.0000e+01, 1.0000e+00, 6.0000e+00, 4.9000e+01, 5.5000e+01, 7.0000e+00,
#          5.2200e+02]])
# tensor([0.8085, 0.4459, 0.2750, 0.9004, 0.7824, 0.6790, 0.7676])

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(15,10))


class_names = ['Surprise' , 'Fear' , 'Disgust' , 'Happiness' , 'Sadness' ,'Anger' ,'Neutral']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 69.0, 'Predicted label')

# %%
torch.save(model.state_dict() , 'best_model.pth')
